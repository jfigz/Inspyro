# %%
# Bienvenido a Inspyro Notebook
print('¡Hola desde Jupyter Notebook!')
# Out:
# ¡Hola desde Jupyter Notebook!

# %%
P_kN = 18.0
L_m = 3.2
M_kNm = P_kN * L_m / 4.0
print(f"M = {M_kNm:.2f} kN m")
# Out:
# M = 14.40 kN m

# %%
doc_reset(hard=True)

with build_doc(block_id="cover", order=10) as builder:
    builder.heading("MCP only visibility probe", level=1)
    builder.text("Notebook creado y ejecutado solo via MCP real.")

with build_doc(block_id="results", order=20) as builder:
    builder.heading("Resultados", level=2)
    builder.text(f"M = {M_kNm:.2f} kN m")
