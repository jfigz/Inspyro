# %%
# Bienvenido a Inspyro Notebookprint('¡Hola desde Jupyter Notebook!')

# %%
doc_reset()
with build_doc(order=1) as doc:
    doc.heading('Smoke Title', level=1)
    doc.text('hello from MCP local smoke')
print('doc ok')
# Out:
# doc ok
